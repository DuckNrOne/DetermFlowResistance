# %%
import RiseAnalysis as ra

# %%
ra.preview_video()
# Out:
# Input File: C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\67mm\07lmin.mp4

# %%
ra.start_analysis_file()
# Out:
# File: C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\67mm\11lmin.mp4
# [PROCESS STARTED]
# C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\67mm\11lmin.mp4
# 1236
# 0%
# 10%
# 20%
# 30%
# C:\Users\Antony\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# 40%
# 50%
# 60%
# 70%
# 80%
# 90%
# Bevor Sdtev
# PROCESS COMPLETED
# ERGEBNISSE
# Winkel Durchschnitt: -47.1451633251683°
# Winkel min: -74.69205485908122°
# Winkel max: 49.372801187484974°
# StDev: 35.13182101367501°
#
# After Stdev
# PROCESS COMPLETED

# %%
ra.start_analysis_file()
# Out:
# File: C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\67mm\11lmin.mp4
# [PROCESS STARTED]
# C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\67mm\11lmin.mp4
# 1236
# 0%
# 10%
# 20%
# 30%
# C:\Users\Antony\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# 40%
# 50%
# 60%
# 70%
# 80%
# C:\Users\Antony\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:128: RuntimeWarning: divide by zero encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# 90%
# Bevor Sdtev
# PROCESS COMPLETED
# ERGEBNISSE
# Winkel Durchschnitt: -67.70609604872621°
# Winkel min: -74.95530228692417°
# Winkel max: -57.338408112830926°
# StDev: 3.6978599444366522°
#
# After Stdev
# PROCESS COMPLETED

# %%
ra.start_analysis_file()
# Out:
# File: C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\67mm\11lmin.mp4
# [PROCESS STARTED]
# C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\67mm\11lmin.mp4
# 1236
# 0%
# 10%
# 20%
# 30%
# C:\Users\Antony\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# 40%
# 50%
# 60%
# 70%
# 80%
# 90%
# Bevor Sdtev
# PROCESS COMPLETED
# ERGEBNISSE
# Winkel Durchschnitt: -69.00475811253803°
# Winkel min: -75.69817164709097°
# Winkel max: -58.80725642735119°
# StDev: 3.5001708603283217°
#
# After Stdev
# PROCESS COMPLETED
