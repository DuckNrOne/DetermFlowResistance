# %%
import RiseAnalysis as ra

# %%
ra.preview_video()
# Out:
# Input File: C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\8mm\07lmin.mp4

# %%
ra.start_analysis_file()
# Out:
# File: C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\8mm\07lmin.mp4
# [PROCESS STARTED]
# C:\Users\Antony\Google Drive\Seminarfach\09_Messung\Testmessung007\8mm\07lmin.mp4
# 1404
# 0%
# 10%
# 20%
# 30%
# 40%
# C:\Users\Antony\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:116: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# C:\Users\Antony\Anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:128: RuntimeWarning: divide by zero encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)
# 50%
# 60%
# 70%
# 80%
# 90%
# Bevor Sdtev
# PROCESS COMPLETED
# ERGEBNISSE
# Winkel Durchschnitt: -82.16107439070112°
# Winkel min: -84.99131207439537°
# Winkel max: -79.56270207914167°
# StDev: 0.9860079876874571°
#
# After Stdev
# PROCESS COMPLETED
